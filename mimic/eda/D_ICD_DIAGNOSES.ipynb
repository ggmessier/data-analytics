# %%
import numpy as np
import pandas as pd
import datetime
import copy
import time
import os
import re
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import operator

from tqdm.auto import tqdm, trange
from tqdm.notebook import tqdm
from datetime import timedelta

tqdm.pandas()

# %%
# Edit to point to your MIMIC directory.
dataDirStr = '/Users/gmessier/data/mimic-1.4/'

# %%
d_icd_diagnoses_df = pd.read_csv(dataDirStr + "D_ICD_DIAGNOSES.csv")
d_icd_diagnoses_df.columns = d_icd_diagnoses_df.columns.str.lower()
d_icd_diagnoses_df
# Out:
#        row_id icd9_code               short_title  \
# 0         174     01166     TB pneumonia-oth test
# 1         175     01170    TB pneumothorax-unspec
# 2         176     01171   TB pneumothorax-no exam
# 3         177     01172  TB pneumothorx-exam unkn
# 4         178     01173  TB pneumothorax-micro dx
# ...       ...       ...                       ...
# 14562   14432     V7399     Scrn unspcf viral dis
# 14563   14433      V740     Screening for cholera
# 14564   14434      V741    Screening-pulmonary TB
# 14565   14435      V742     Screening for leprosy
# 14566   14436      V743  Screening for diphtheria
#
#                                               long_title
# 0      Tuberculous pneumonia [any form], tubercle bac...
# 1                  Tuberculous pneumothorax, unspecified
# 2      Tuberculous pneumothorax, bacteriological or h...
# 3      Tuberculous pneumothorax, bacteriological or h...
# 4      Tuberculous pneumothorax, tubercle bacilli fou...
# ...                                                  ...
# 14562  Special screening examination for unspecified ...
# 14563                  Screening examination for cholera
# 14564   Screening examination for pulmonary tuberculosis
# 14565  Screening examination for leprosy (Hansen's di...
# 14566               Screening examination for diphtheria
#
# [14567 rows x 4 columns]

# %% [markdown]
# `D_ICD_DIAGNOSES` defines International Classification of Diseases Version 9 (ICD-9) codes for diagnoses. These codes are assigned at the end of the patient’s stay and are used by the hospital to bill for care provided.

# %% [markdown]
# `icd9_code` is the International Coding Definitions Version 9 (ICD-9) code. Each code corresponds to a single diagnostic concept.

# %% [markdown]
# The `short_title` and `long_title` fields provide a brief definition for the given diagnosis code in ICD9_CODE.

# %%
d_icd_diagnoses_df.dtypes
# Out:
# row_id          int64
# icd9_code      object
# short_title    object
# long_title     object
# dtype: object

# %%
tbl = d_icd_diagnoses_df

# %%
idx = tbl.icd9_code.str.contains('^2|^E85')

# %%
tbl.loc[idx]
# Out:
#        row_id icd9_code               short_title  \
# 1142     1524     20076   Large cell lymph pelvic
# 1208      930     20221     Sezary's disease head
# 1209      931     20222   Sezary's disease thorax
# 1210      932     20223    Sezary's disease abdom
# 1211      933     20224   Sezary's disease axilla
# ...       ...       ...                       ...
# 13993   11615     E8585    Acc poisn-metabol agnt
# 13994   11616     E8586  Acc poisn-muscl/resp agt
# 13995   11617     E8587  Acc poisn-skin/eent agnt
# 13996   11618     E8588    Acc poisoning-drug NEC
# 13997   11619     E8589    Acc poisoning-drug NOS
#
#                                               long_title
# 1142        Large cell lymphoma, intrapelvic lymph nodes
# 1208   Sezary's disease, lymph nodes of head, face, a...
# 1209         Sezary's disease, intrathoracic lymph nodes
# 1210       Sezary's disease, intra-abdominal lymph nodes
# 1211   Sezary's disease, lymph nodes of axilla and up...
# ...                                                  ...
# 13993  Accidental poisoning by water, mineral, and ur...
# 13994  Accidental poisoning by agents primarily actin...
# 13995  Accidental poisoning by agents primarily affec...
# 13996      Accidental poisoning by other specified drugs
# 13997           Accidental poisoning by unspecified drug
#
# [1311 rows x 4 columns]
